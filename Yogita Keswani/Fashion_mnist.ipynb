# %% [markdown]
# # Fashion-MNIST
# Fashion-MNIST is a dataset of images consisting of a training set of 60,000 examples and a
# test set of 10,000 examples. Each example is a 28x28 grayscale image, associated with a label
# from 10 classes.
#
# The objective is to identify (predict) different fashion products from the given images using a CNN model.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Import the required libraries

# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from keras.datasets import fashion_mnist
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten

# %%
# Load the fashion-mnist pre-shuffled train data and test data
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

print("x_train shape:", x_train.shape, "y_train shape:", y_train.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# x_train shape: (60000, 28, 28) y_train shape: (60000,)

# %% [markdown]
# ## Visualize the data

# %%
# Print the number of training and test datasets
print(x_train.shape[0], 'train set')
print(x_test.shape[0], 'test set')
# Out:
# 60000 train set
# 10000 test set

# %%
# Define the text labels
fashion_mnist_labels = ["T-shirt/top",  # index 0
                        "Trouser",      # index 1
                        "Pullover",     # index 2 
                        "Dress",        # index 3 
                        "Coat",         # index 4
                        "Sandal",       # index 5
                        "Shirt",        # index 6 
                        "Sneaker",      # index 7 
                        "Bag",          # index 8 
                        "Ankle boot"]   # index 9

# Image index, any number between 0 and 59,999
img_index = 5
# y_train contains the lables, ranging from 0 to 9
label_index = y_train[img_index]
# Print the label, for example 2 Pullover
print ("y = " + str(label_index) + " " +(fashion_mnist_labels[label_index]))
# Display one of the images from the training dataset
plt.imshow(x_train[img_index])
# Out:
# y = 2 Pullover

# %% [markdown]
# ## Data normalization
# Normalize the data dimensions so that they are of approximately the same scale.

# %%
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# %%
print("Number of train data - " + str(len(x_train)))
print("Number of test data - " + str(len(x_test)))
# Out:
# Number of train data - 60000
# Number of test data - 10000

# %% [markdown]
# ## Split the data into train/validation/test data sets

# %%
# Further break training data into train / validation sets 
(x_train, x_valid) = x_train[5000:], x_train[:5000] 
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# Reshape input data from (28, 28) to (28, 28, 1)
w, h = 28, 28
x_train = x_train.reshape(x_train.shape[0], w, h, 1)
x_valid = x_valid.reshape(x_valid.shape[0], w, h, 1)
x_test = x_test.reshape(x_test.shape[0], w, h, 1)

# %%
# One-hot encode the labels
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_valid = tf.keras.utils.to_categorical(y_valid, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# Print training set shape
print("x_train shape:", x_train.shape, "y_train shape:", y_train.shape)

# Print the number of training, validation, and test datasets
print(x_train.shape[0], 'train set')
print(x_valid.shape[0], 'validation set')
print(x_test.shape[0], 'test set')
# Out:
# x_train shape: (55000, 28, 28, 1) y_train shape: (55000, 10)
# 55000 train set
# 5000 validation set
# 10000 test set

# %% [markdown]
# ## Build the model

# %%
model = Sequential()

# define the input shape in the first layer of the neural network
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu', input_shape=(28,28,1))) 
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))

model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))

model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

# Take a look at the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 64)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 32)        8224
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 32)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 7, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1568)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               401664
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 412,778
# Trainable params: 412,778
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile the model

# %%
model.compile(loss='categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])

# %% [markdown]
# ### Train the model

# %%
from keras.callbacks import ModelCheckpoint

checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose = 1, save_best_only=True)
model.fit(x_train,
         y_train,
         batch_size=64,
         epochs=10,
         validation_data=(x_valid, y_valid),
         callbacks=[checkpointer])
# Out:
# Epoch 1/10
# 860/860 [==============================] - 86s 82ms/step - loss: 0.8502 - accuracy: 0.6858 - val_loss: 0.3764 - val_accuracy: 0.8688
#
# Epoch 00001: val_loss improved from inf to 0.37644, saving model to model.weights.best.hdf5
# Epoch 2/10
# 860/860 [==============================] - 69s 81ms/step - loss: 0.4237 - accuracy: 0.8463 - val_loss: 0.3176 - val_accuracy: 0.8838
#
# Epoch 00002: val_loss improved from 0.37644 to 0.31756, saving model to model.weights.best.hdf5
# Epoch 3/10
# 860/860 [==============================] - 70s 81ms/step - loss: 0.3707 - accuracy: 0.8666 - val_loss: 0.2886 - val_accuracy: 0.8942
#
# Epoch 00003: val_loss improved from 0.31756 to 0.28860, saving model to model.weights.best.hdf5
# Epoch 4/10
# 860/860 [==============================] - 70s 81ms/step - loss: 0.3404 - accuracy: 0.8736 - val_loss: 0.2692 - val_accuracy: 0.9024
#
# Epoch 00004: val_loss improved from 0.28860 to 0.26915, saving model to model.weights.best.hdf5
# Epoch 5/10
# 860/860 [==============================] - 70s 81ms/step - loss: 0.3209 - accuracy: 0.8827 - val_loss: 0.2526 - val_accuracy: 0.9082
#
# Epoch 00005: val_loss improved from 0.26915 to 0.25258, saving model to model.weights.best.hdf5
# Epoch 6/10
# 860/860 [==============================] - 70s 82ms/step - loss: 0.3066 - accuracy: 0.8874 - val_loss: 0.2481 - val_accuracy: 0.9068
#
# Epoch 00006: val_loss improved from 0.25258 to 0.24809, saving model to model.weights.best.hdf5
# Epoch 7/10
# 860/860 [==============================] - 70s 82ms/step - loss: 0.2875 - accuracy: 0.8935 - val_loss: 0.2372 - val_accuracy: 0.9110
#
# Epoch 00007: val_loss improved from 0.24809 to 0.23725, saving model to model.weights.best.hdf5
# Epoch 8/10
# 860/860 [==============================] - 70s 82ms/step - loss: 0.2823 - accuracy: 0.8954 - val_loss: 0.2325 - val_accuracy: 0.9150
#
# Epoch 00008: val_loss improved from 0.23725 to 0.23251, saving model to model.weights.best.hdf5
# Epoch 9/10
# 860/860 [==============================] - 71s 82ms/step - loss: 0.2683 - accuracy: 0.9023 - val_loss: 0.2234 - val_accuracy: 0.9148
#
# Epoch 00009: val_loss improved from 0.23251 to 0.22345, saving model to model.weights.best.hdf5
# Epoch 10/10
# 860/860 [==============================] - 71s 83ms/step - loss: 0.2615 - accuracy: 0.9025 - val_loss: 0.2218 - val_accuracy: 0.9146
#
# Epoch 00010: val_loss improved from 0.22345 to 0.22182, saving model to model.weights.best.hdf5

# %% [markdown]
# ### Load Model with the best validation accuracy

# %%
# Load the weights with the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### Test Accuracy

# %%
# Evaluate the model on test set
score = model.evaluate(x_test, y_test, verbose=0)

# Print test accuracy
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.9125000238418579

# %% [markdown]
# ## Visualize prediction

# %%
y_hat = model.predict(x_test)

# Plot a random sample of 10 test images, their predicted labels and ground truth
figure = plt.figure(figsize=(20, 8))
for i, index in enumerate(np.random.choice(x_test.shape[0], size=15, replace=False)):
    ax = figure.add_subplot(3, 5, i + 1, xticks=[], yticks=[])
    # Display each image
    ax.imshow(np.squeeze(x_test[index]))
    predict_index = np.argmax(y_hat[index])
    true_index = np.argmax(y_test[index])
    # Set the title for each image
    ax.set_title("{} ({})".format(fashion_mnist_labels[predict_index], 
                                  fashion_mnist_labels[true_index]),
                                  color=("green" if predict_index == true_index else "red"))
